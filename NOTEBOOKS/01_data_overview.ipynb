# %% [markdown]
# ## Exploratory Data Analysis – Hospital Readmission Risk in Diabetic Patients
#
#
# Author: muhameed razin v
#
# Duration: 5 Days
#
# Tools: Python, pandas, numpy, matplotlib, seaborn
#
# ## Overview
#
# Hospital readmissions within 30 days represent a critical concern in healthcare systems due to increased financial burden, resource utilization, and potential indicators of inadequate post-discharge care. Diabetic patients, in particular, are at a higher risk of complications leading to readmission.
#
# This project performs a structured exploratory data analysis (EDA) on hospital encounter data to identify patterns and factors influencing readmission risk. The goal is to generate data-driven insights that support early risk identification, improve discharge planning, and assist healthcare management in reducing avoidable readmissions.
# DAY 1 — Understanding & Initial Profiling
#
# ## Dataset Description:
#
# Dataset contains hospital encounters of diabetic patients
#
# 130 US hospitals
#
# Period: 1999–2008
#
# Each row represents one hospital visit
#
# Goal: Analyze factors affecting readmission

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Hp\OneDrive\Desktop\EDA PROJECT\diabetic_data.csv")
df.head()
# Out:
#    encounter_id  patient_nbr       race  gender       age  admission_type_id  \
# 0      72091308     20123568  Caucasian  Female   [70-80)                  1
# 1      72848634     20377854  Caucasian  Female   [60-70)                  2
# 2      73062156     20408121  Caucasian  Female  [90-100)                  1
# 3      73731852     20542797  Caucasian    Male   [70-80)                  1
# 4      81355914      7239654  Caucasian  Female   [70-80)                  1
#
#    discharge_disposition_id  admission_source_id  days_in_hospital payer_code  \
# 0                        22                    7                 7         MC
# 1                         1                    1                 3         MC
# 2                         1                    7                 4         MC
# 3                         2                    7                10         MC
# 4                         3                    6                12         UN
#
#    ... number_diagnoses  metformin  repaglinide  glimepiride  glyburide  \
# 0  ...                9         No           No           No         No
# 1  ...                6         No           No           No         No
# 2  ...                6         No           No       Steady         No
# 3  ...                6     Steady           No           No         No
# 4  ...                5         No           No           No         No
#
#    pioglitazone  rosiglitazone acarbose insulin readmitted
# 0            Up             No       No  Steady         NO
# 1            No             No       No  Steady         NO
# 2            No             No       No      No         NO
# 3            No             No       No  Steady         NO
# 4            No             No       No  Steady         NO
#
# [5 rows x 30 columns]

# %%
df.tail()
# Out:
#        encounter_id  patient_nbr       race  gender      age  \
# 27910     443739044    106595208  Caucasian    Male  [70-80)
# 27911     443793668     47293812  Caucasian    Male  [80-90)
# 27912     443804570     33230016  Caucasian  Female  [70-80)
# 27913     443816024    106392411  Caucasian  Female  [70-80)
# 27914     443857166     31693671  Caucasian  Female  [80-90)
#
#        admission_type_id  discharge_disposition_id  admission_source_id  \
# 27910                  2                         6                    7
# 27911                  1                        13                    7
# 27912                  1                        22                    7
# 27913                  3                         6                    1
# 27914                  2                         3                    7
#
#        days_in_hospital payer_code  ... number_diagnoses  metformin  \
# 27910                 6         MC  ...                9         No
# 27911                 3         MC  ...                9         No
# 27912                 8         MC  ...                9         No
# 27913                 3         MC  ...                9     Steady
# 27914                10         MC  ...                9         No
#
#        repaglinide  glimepiride  glyburide  pioglitazone  rosiglitazone  \
# 27910           No           No         No            No             No
# 27911           No           No         Up            No         Steady
# 27912           No           No         No            No             No
# 27913           No           No         No            No             No
# 27914           No           No         No        Steady             No
#
#       acarbose insulin readmitted
# 27910       No      Up         NO
# 27911       No    Down         NO
# 27912       No  Steady        >30
# 27913       No  Steady         NO
# 27914       No      Up         NO
#
# [5 rows x 30 columns]

# %%
df.shape
# Out:
# (27915, 30)

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'days_in_hospital', 'payer_code', 'doctors_dep', 'num_lab_procedures',
#        'num_procedures', 'num_medications', 'number_outpatient',
#        'number_emergency', 'number_inpatient', 'primary_diagnosis',
#        'secondary_diagnosis', 'additional_diagnosis', 'number_diagnoses',
#        'metformin', 'repaglinide', 'glimepiride', 'glyburide', 'pioglitazone',
#        'rosiglitazone', 'acarbose', 'insulin', 'readmitted'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27915 entries, 0 to 27914
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   encounter_id              27915 non-null  int64
#  1   patient_nbr               27915 non-null  int64
#  2   race                      27915 non-null  object
#  3   gender                    27915 non-null  object
#  4   age                       27915 non-null  object
#  5   admission_type_id         27915 non-null  int64
#  6   discharge_disposition_id  27915 non-null  int64
#  7   admission_source_id       27915 non-null  int64
#  8   days_in_hospital          27915 non-null  int64
#  9   payer_code                27915 non-null  object
#  10  doctors_dep               27915 non-null  object
#  11  num_lab_procedures        27915 non-null  int64
#  12  num_procedures            27915 non-null  int64
#  13  num_medications           27915 non-null  int64
#  14  number_outpatient         27915 non-null  int64
#  15  number_emergency          27915 non-null  int64
#  16  number_inpatient          27915 non-null  int64
#  17  primary_diagnosis         27915 non-null  object
#  18  secondary_diagnosis       27915 non-null  object
#  19  additional_diagnosis      27915 non-null  object
#  20  number_diagnoses          27915 non-null  int64
#  21  metformin                 27915 non-null  object
#  22  repaglinide               27915 non-null  object
#  23  glimepiride               27915 non-null  object
#  24  glyburide                 27915 non-null  object
#  25  pioglitazone              27915 non-null  object
#  26  rosiglitazone             27915 non-null  object
#  27  acarbose                  27915 non-null  object
#  28  insulin                   27915 non-null  object
#  29  readmitted                27915 non-null  object
# dtypes: int64(13), object(17)
# memory usage: 6.4+ MB

# %%
df.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  2.791500e+04  2.791500e+04       27915.000000
# mean   1.841158e+08  5.599867e+07           2.011965
# std    8.394616e+07  3.736242e+07           0.940823
# min    7.209131e+07  7.290000e+02           1.000000
# 25%    1.192240e+08  2.400127e+07           1.000000
# 50%    1.607558e+08  4.322858e+07           2.000000
# 75%    2.302870e+08  9.185323e+07           3.000000
# max    4.438572e+08  1.893659e+08           6.000000
#
#        discharge_disposition_id  admission_source_id  days_in_hospital  \
# count              27915.000000         27915.000000      27915.000000
# mean                   2.911374             4.940570          4.294107
# std                    4.269688             3.512699          2.942521
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# 50%                    1.000000             7.000000          4.000000
# 75%                    3.000000             7.000000          6.000000
# max                   28.000000            22.000000         14.000000
#
#        num_lab_procedures  num_procedures  num_medications  number_outpatient  \
# count        27915.000000    27915.000000     27915.000000       27915.000000
# mean            40.745227        1.458786        16.084077           0.282680
# std             19.871317        1.743732         8.579285           0.983899
# min              1.000000        0.000000         1.000000           0.000000
# 25%             29.000000        0.000000        10.000000           0.000000
# 50%             42.000000        1.000000        15.000000           0.000000
# 75%             54.000000        2.000000        20.000000           0.000000
# max            132.000000        6.000000        81.000000          38.000000
#
#        number_emergency  number_inpatient  number_diagnoses
# count      27915.000000      27915.000000      27915.000000
# mean           0.301702          0.655275          7.240587
# std            1.414151          1.348572          1.973913
# min            0.000000          0.000000          1.000000
# 25%            0.000000          0.000000          5.000000
# 50%            0.000000          0.000000          8.000000
# 75%            0.000000          1.000000          9.000000
# max           76.000000         16.000000         16.000000

# %%
df.nunique().sort_values()
# Out:
# gender                          2
# readmitted                      3
# acarbose                        4
# rosiglitazone                   4
# metformin                       4
# pioglitazone                    4
# glyburide                       4
# glimepiride                     4
# insulin                         4
# repaglinide                     4
# race                            6
# admission_type_id               6
# num_procedures                  7
# age                            10
# admission_source_id            14
# days_in_hospital               14
# number_diagnoses               15
# payer_code                     16
# number_inpatient               17
# number_outpatient              20
# discharge_disposition_id       23
# number_emergency               31
# doctors_dep                    57
# num_medications                75
# num_lab_procedures            110
# primary_diagnosis             576
# secondary_diagnosis           583
# additional_diagnosis          594
# patient_nbr                 20367
# encounter_id                27915
# dtype: int64

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# encounter_id                0
# patient_nbr                 0
# insulin                     0
# acarbose                    0
# rosiglitazone               0
# pioglitazone                0
# glyburide                   0
# glimepiride                 0
# repaglinide                 0
# metformin                   0
# number_diagnoses            0
# additional_diagnosis        0
# secondary_diagnosis         0
# primary_diagnosis           0
# number_inpatient            0
# number_emergency            0
# number_outpatient           0
# num_medications             0
# num_procedures              0
# num_lab_procedures          0
# doctors_dep                 0
# payer_code                  0
# days_in_hospital            0
# admission_source_id         0
# discharge_disposition_id    0
# admission_type_id           0
# age                         0
# gender                      0
# race                        0
# readmitted                  0
# dtype: int64

# %% [markdown]
# ## Initial Observations Section:
#
#
# Age is stored as categorical ranges
#
# Some categorical columns have many unique categories
#
# Potential outliers may exist in numeric columns
#
# High imbalance possible in readmitted variable

# %%
df['readmitted'].value_counts()
# Out:
# readmitted
# NO     16006
# >30     8947
# <30     2962
# Name: count, dtype: int64

# %% [markdown]
# ## Day 1 Summary:
#
# Dataset loaded successfully
#
# Structure examined
#
# Numerical and categorical variables separated
#
# Target variable distribution analyzed
#
# Data quality issues logged

# %%
df.to_csv("day1_output.csv", index=False)
